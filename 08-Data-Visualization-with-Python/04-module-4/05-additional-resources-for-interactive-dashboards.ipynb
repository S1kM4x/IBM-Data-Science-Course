# %% [markdown]
# ## Additional Resources for Interactive Dashboards
#
# 1. [Python decorators reference 1](https://realpython.com/primer-on-python-decorators/)
# 2. [Python decorators reference 2](https://peps.python.org/pep-0318/#current-syntax)
# 3. [Callbacks with example](https://dash.plotly.com/basic-callbacks)
# 4. [Dash app gallery](https://dash.gallery/Portal/)
# 5. [Dash community components](https://community.plotly.com/t/community-components-index/60098)
