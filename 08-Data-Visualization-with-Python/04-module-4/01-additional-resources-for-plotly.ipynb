# %% [markdown]
# ## Addtional Resources for Plotly
#
# 1. [Plotly python](https://plotly.com/python/getting-started/)
# 2. [Plotly graph objects with example](https://plotly.com/python/graph-objects/)
# 3. [Plotly express](https://plotly.com/python/plotly-express/)
# 4. [API reference](https://plotly.com/python-api-reference/)
#
#  Additional useful resources
#
#  1. [Plotly cheatsheet](https://images.plot.ly/plotly-documentation/images/plotly_js_cheat_sheet.pdf)
#  2. [Plotly community](https://community.plotly.com/c/plotly-python/5)
#  3. [Related blogs](https://plotlygraphs.medium.com/)
#  4. [Open-source datasets](https://developer.ibm.com/exchanges/data/)
