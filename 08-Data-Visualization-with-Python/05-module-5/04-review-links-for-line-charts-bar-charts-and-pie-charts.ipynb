# %% [markdown]
# ## REVIEW LINKS for Line charts, Bar charts and Pie charts:
#
# 1. [Line Chart](https://plotly.com/python/line-charts/)
# 2. [Bar Chart](https://plotly.com/python/bar-charts/)
# 3. [Pie Chart](https://plotly.com/python/pie-charts/)
